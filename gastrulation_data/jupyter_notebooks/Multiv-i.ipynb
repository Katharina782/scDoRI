# %%
import scanpy as sc
import scvi

# %%
#pvi.save("/omics/groups/OE0533/internal/katharina/scDoRI/gastrulation_data/peakVI_trained_model", overwrite=True)

# %% [markdown]
# # No Batch Correction

# %%
# load anndata with latent space
adata = scvi.data.read_h5ad("mvi_default/anndata_object")

# %%
# load trained model
mvi = scvi.model.MULTIVI.load("mvi_default/", adata=adata)
# Out:
# /omics/groups/OE0533/internal/katharina/scvi2/lib/python3.7/site-packages/scvi/data/_utils.py:102: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
#   "Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization."

# %% [markdown]
# ## Visualize and analyze the latent space

# %%
# compute the k-nearest-neighbor graph that is used in both clustering and umap algorithms
sc.pp.neighbors(adata, use_rep="X_multivi")
# compute the umap
sc.tl.umap(adata, min_dist=0.2)

# %%
colPalette_celltypes = ['#532C8A',
 '#c19f70',
 '#f9decf',
 '#c9a997',
 '#B51D8D',
 '#3F84AA',
 '#9e6762',
 '#354E23',
 '#F397C0',
 '#ff891c',
 '#635547',
 '#C72228',
 '#f79083',
 '#EF4E22',
 '#989898',
 '#7F6874',
 '#8870ad',
 '#647a4f',
 '#EF5A9D',
 '#FBBE92',
 '#139992',
 '#cc7818',
 '#DFCDE4',
 '#8EC792',
 '#C594BF',
 '#C3C388',
 '#0F4A9C',
 '#FACB12',
 '#8DB5CE',
 '#1A1A1A',
 '#C9EBFB',
 '#DABE99',
 '#65A83E',
 '#005579',
 '#CDE088',
 '#f7f79e',
 '#F6BFCB']

# %%
sc.set_figure_params(figsize=(10,10))

sc.pl.umap(
    adata,
    color='celltype.mapped_seurat',
    ncols=2,
    size=15,
    palette = colPalette_celltypes)

# %%
sc.set_figure_params(figsize=(6,6))
sc.pl.umap(
    adata,
    color=["sample"],
    ncols=2,
    frameon=False,
    size=15
)

# %% [markdown]
# # 20 dimensional latent space

# %%
# load anndata with latent space
adata = scvi.data.read_h5ad("mvi_20_dim/anndata_object")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 45991 × 186627
#     obs: 'BlacklistRatio', 'nDiFrags', 'nFrags', 'nMonoFrags', 'nMultiFrags', 'NucleosomeRatio', 'PassQC', 'PromoterRatio', 'ReadsInBlacklist', 'ReadsInPromoter', 'ReadsInTSS', 'Sample', 'TSSEnrichment', 'barcode', 'sample', 'nFeature_RNA', 'nCount_RNA', 'mitochondrial_percent_RNA', 'ribosomal_percent_RNA', 'stage', 'pass_rnaQC', 'doublet_score', 'doublet_call', 'celltype.mapped_mnn', 'celltype.score_mnn', 'closest.cell', 'celltype.mapped_seurat', 'celltype.score_seurat', 'TSSEnrichment_atac', 'ReadsInTSS_atac', 'PromoterRatio_atac', 'NucleosomeRatio_atac', 'nFrags_atac', 'BlacklistRatio_atac', 'ReadsInPeaks', 'FRIP', 'modality', '_scvi_batch', '_scvi_labels'
#     var: 'ID', 'chr', 'end', 'start', 'modality', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'celltype_colors'
#     obsm: 'X_multivi', '_scvi_extra_categorical_covs'

# %%
# load trained model
mvi = scvi.model.MULTIVI.load("mvi_20_dim/", adata=adata)
# Out:
# /omics/groups/OE0533/internal/katharina/scvi2/lib/python3.7/site-packages/scvi/data/_utils.py:102: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
#   "Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization."

# %%
# compute the k-nearest-neighbor graph that is used in both clustering and umap algorithms
sc.pp.neighbors(adata, use_rep="X_multivi")
# compute the umap
sc.tl.umap(adata, min_dist=0.2)

# %%
sc.set_figure_params(figsize=(10,10))

sc.pl.umap(
    adata,
    color='celltype.mapped_seurat',
    ncols=2,
    size=15,
    palette = colPalette_celltypes)

# %%
sc.set_figure_params(figsize=(6,6))
sc.pl.umap(
    adata,
    color=["sample"],
    ncols=2,
    frameon=False,
    size=15
)
